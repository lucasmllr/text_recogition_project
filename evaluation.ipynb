# %%
import matplotlib.pyplot as plt
from pipeline import read
from processing import load_img, rescale
from arguments import Arguments
import numpy as np

# %%
args = Arguments()
args.documentation = True
args.method = 'mser'
args.space_threshold = .5
args.t_color = 0.2
args.t_A = 5
args.C_d = 5
args.delta = 10

# %%
img = load_img('IBANs/originals/IMG_0878.jpg', args)
print('image range:', np.max(img), np.min(img))
results = read(img, args)
[print(line) for line in results];
# Out:
# image range: 223 3
# /Users/lucasmoeller/Documents/uni/FunML/project/model.py:42: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(out)
# Zwischensumme f
# J Skonto Q 00oX
# 1 0 t
# Summe inkI r (
# Enth Mwst (in 4yQ) 19 00 1
# 1 t
# Rmhnungmtrag f
# Gesamtbetrag T
# r
# Bankinstitut Deutsche Bank
# lBAN DE3076070024072M2O900
# BlClSWlm CMe DEUTDEDB760
# 2
# @ingungeH Bereits miichen
# mingungen frei Haus
# 2V n d Versichede5 Paket
